# %% [raw]
# # CSV file:
# --> Comma Separated Values
# --> Universaly Use
# --> Easy to Understand
# --> Quick to Create

# %%
import pandas as pd

# %%
path = r"C:\Users\Sandeep\python lerning\Dataset\Movieratingdata.csv"
#path = "C:\\Users\\Helly\\Desktop\\DATA\\2. Python libraries\\2) Pandas\\Dataset\\Movieratingdata.csv"

# %% [raw]
# # Site for DataSet "https://www.kaggle.com"

# %% [markdown]
# # Read csv file

# %%
df = pd.read_csv(path)
df
# Out:
#      USER_ID  MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR  \
# 0          1   4642044                     Riot              2015
# 1          2   1925518          The Protector 2              2013
# 2          3    372784            Batman Begins              2005
# 3          4   1390411  In the Heart of the Sea              2015
# 4          5   6306064                   Adrift              2018
# ..       ...       ...                       ...              ...
# 495      496   1846589            Hunter Killer              2018
# 496      497   4196776             Jason Bourne              2016
# 497      498   7456310                     Anna              2019
# 498      499   8106534            6 Underground              2019
# 499      500   2302755       Olympus Has Fallen              2013
#
#                                                 GENRES  RATING  Unnamed: 6  \
# 0                                               Action     8.0         NaN
# ...

# %% [markdown]
# # columns name

# %%
df.columns
# Out:
# Index(['USER_ID', 'MOVIE_ID', 'MOVIE_TITLE', 'PRODUCTION_YEAR', 'GENRES',
#        'RATING', 'Unnamed: 6', 'Unnamed: 7', 'GENRES.1', 'Unnamed: 9'],
#       dtype='object')

# %% [markdown]
# # find datatype

# %%
df.dtypes
# Out:
# USER_ID              int64
# MOVIE_ID             int64
# MOVIE_TITLE         object
# PRODUCTION_YEAR      int64
# GENRES              object
# RATING             float64
# Unnamed: 6         float64
# Unnamed: 7         float64
# GENRES.1            object
# Unnamed: 9         float64
# dtype: object

# %% [markdown]
# # change datatype

# %%
df["USER_ID"] = df["USER_ID"].astype(float)

# %%
df
# Out:
#      USER_ID  MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR  \
# 0        1.0   4642044                     Riot              2015
# 1        2.0   1925518          The Protector 2              2013
# 2        3.0    372784            Batman Begins              2005
# 3        4.0   1390411  In the Heart of the Sea              2015
# 4        5.0   6306064                   Adrift              2018
# ..       ...       ...                       ...              ...
# 495    496.0   1846589            Hunter Killer              2018
# 496    497.0   4196776             Jason Bourne              2016
# 497    498.0   7456310                     Anna              2019
# 498    499.0   8106534            6 Underground              2019
# 499    500.0   2302755       Olympus Has Fallen              2013
#
#                                                 GENRES  RATING  Unnamed: 6  \
# 0                                               Action     8.0         NaN
# ...

# %%
df.dtypes
# Out:
# USER_ID            float64
# MOVIE_ID             int64
# MOVIE_TITLE         object
# PRODUCTION_YEAR      int64
# GENRES              object
# RATING             float64
# Unnamed: 6         float64
# Unnamed: 7         float64
# GENRES.1            object
# Unnamed: 9         float64
# dtype: object

# %%
df = pd.read_csv(path,dtype={"MOVIE_ID":"float64","PRODUCTION_YEAR":"float64","USER_ID":"float64"})
df
# Out:
#      USER_ID   MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR  \
# 0        1.0  4642044.0                     Riot            2015.0
# 1        2.0  1925518.0          The Protector 2            2013.0
# 2        3.0   372784.0            Batman Begins            2005.0
# 3        4.0  1390411.0  In the Heart of the Sea            2015.0
# 4        5.0  6306064.0                   Adrift            2018.0
# ..       ...        ...                       ...              ...
# 495    496.0  1846589.0            Hunter Killer            2018.0
# 496    497.0  4196776.0             Jason Bourne            2016.0
# 497    498.0  7456310.0                     Anna            2019.0
# 498    499.0  8106534.0            6 Underground            2019.0
# 499    500.0  2302755.0       Olympus Has Fallen            2013.0
#
#                                                 GENRES  RATING  Unnamed: 6  \
# 0                                               Action     8.0         NaN
# ...

# %% [markdown]
# # nrow , skiprows and usecols while csv reading

# %%
# nrow
df = pd.read_csv(path,nrows=5)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # nrow
# ----> 2 df = pd.read_csv(path,nrows=5)
#       3 df
#
# NameError: name 'pd' is not defined

# %%
# skiprows
df = pd.read_csv(path,skiprows=5)
df
# Out:
#        5  6306064              Adrift   2018  \
# 0      6  6306064              Adrift   2018
# 1      7  2719848             Everest   2015
# 2      8   462504         Rescue Dawn   2006
# 3      9  1663202        The Revenant   2015
# 4     10  1663202        The Revenant   2015
# ..   ...      ...                  ...   ...
# 490  496  1846589       Hunter Killer   2018
# 491  497  4196776        Jason Bourne   2016
# 492  498  7456310                Anna   2019
# 493  499  8106534       6 Underground   2019
# 494  500  2302755  Olympus Has Fallen   2013
#
#      Action|Adventure|Biography|Drama|Romance|Thriller     4  Unnamed: 6  \
# 0    Action|Adventure|Biography|Drama|Romance|Thriller   5.0         NaN
# 1            Action|Adventure|Biography|Drama|Thriller   6.0         NaN
# 2                 Action|Adventure|Biography|Drama|War   8.0         NaN
# 3             Action|Adventure|Biography|Drama|Western  10.0         NaN
# ...

# %%
df = pd.read_csv(path,skiprows=[1,3,7,10,11])
df
# Out:
#      USER_ID  MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR  \
# 0          2   1925518          The Protector 2              2013
# 1          4   1390411  In the Heart of the Sea              2015
# 2          5   6306064                   Adrift              2018
# 3          6   6306064                   Adrift              2018
# 4          8    462504              Rescue Dawn              2006
# ..       ...       ...                       ...              ...
# 490      496   1846589            Hunter Killer              2018
# 491      497   4196776             Jason Bourne              2016
# 492      498   7456310                     Anna              2019
# 493      499   8106534            6 Underground              2019
# 494      500   2302755       Olympus Has Fallen              2013
#
#                                                 GENRES  RATING  Unnamed: 6  \
# 0                                               Action       5         NaN
# ...

# %%
# usecols
df = pd.read_csv(path,usecols=["MOVIE_TITLE"])
df
# Out:
#                   MOVIE_TITLE
# 0                       Riot
# 1            The Protector 2
# 2              Batman Begins
# 3    In the Heart of the Sea
# 4                     Adrift
# ..                        ...
# 495            Hunter Killer
# 496             Jason Bourne
# 497                     Anna
# 498            6 Underground
# 499       Olympus Has Fallen
#
# [500 rows x 1 columns]

# %%
df = pd.read_csv(path,usecols=["MOVIE_TITLE","PRODUCTION_YEAR","RATING","GENRES"])
df
# Out:
#                   MOVIE_TITLE  PRODUCTION_YEAR  \
# 0                       Riot              2015
# 1            The Protector 2              2013
# 2              Batman Begins              2005
# 3    In the Heart of the Sea              2015
# 4                     Adrift              2018
# ..                        ...              ...
# 495            Hunter Killer              2018
# 496             Jason Bourne              2016
# 497                     Anna              2019
# 498            6 Underground              2019
# 499       Olympus Has Fallen              2013
#
#                                                 GENRES  RATING
# 0                                               Action     8.0
# 1                                               Action     5.0
# 2                                     Action|Adventure     9.0
# 3    Action|Adventure|Biography|Drama|History|Thriller     5.0
# 4    Action|Adventure|Biography|Drama|Romance|Thriller     4.0
# ...

# %%
df = pd.read_csv(path,usecols=[0,3,5])
df
# Out:
#      USER_ID  PRODUCTION_YEAR  RATING
# 0          1             2015     8.0
# 1          2             2013     5.0
# 2          3             2005     9.0
# 3          4             2015     5.0
# 4          5             2018     4.0
# ..       ...              ...     ...
# 495      496             2018     6.0
# 496      497             2016     6.0
# 497      498             2019     7.0
# 498      499             2019     4.0
# 499      500             2013     1.0
#
# [500 rows x 3 columns]

# %% [markdown]
# # set column as index one or more

# %%
df = pd.read_csv(path,index_col=["USER_ID"])
df
# Out:
#          MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR  \
# USER_ID
# 1         4642044                     Riot              2015
# 2         1925518          The Protector 2              2013
# 3          372784            Batman Begins              2005
# 4         1390411  In the Heart of the Sea              2015
# 5         6306064                   Adrift              2018
# ...           ...                       ...              ...
# 496       1846589            Hunter Killer              2018
# 497       4196776             Jason Bourne              2016
# 498       7456310                     Anna              2019
# 499       8106534            6 Underground              2019
# 500       2302755       Olympus Has Fallen              2013
#
#                                                     GENRES  RATING  \
# USER_ID
# 1                                                   Action     8.0
# 2                                                   Action     5.0
# ...

# %%
df.columns
# Out:
# Index(['MOVIE_ID', 'MOVIE_TITLE', 'PRODUCTION_YEAR', 'GENRES', 'RATING',
#        'Unnamed: 6', 'Unnamed: 7', 'GENRES.1', 'Unnamed: 9'],
#       dtype='object')

# %%
df = pd.read_csv(path,index_col=["MOVIE_TITLE","USER_ID"])
df
# Out:
#                                   MOVIE_ID  PRODUCTION_YEAR  \
# MOVIE_TITLE              USER_ID
# Riot                     1         4642044             2015
# The Protector 2          2         1925518             2013
# Batman Begins            3          372784             2005
# In the Heart of the Sea  4         1390411             2015
# Adrift                   5         6306064             2018
# ...                                    ...              ...
# Hunter Killer            496       1846589             2018
# Jason Bourne             497       4196776             2016
# Anna                     498       7456310             2019
# 6 Underground            499       8106534             2019
# Olympus Has Fallen       500       2302755             2013
#
#                                                                              GENRES  \
# MOVIE_TITLE              USER_ID
# Riot                     1                                                   Action
# ...

# %%
df = pd.read_csv(path,index_col=[0,1,2,3])
df
# Out:
#                                                                                                       GENRES  \
# USER_ID MOVIE_ID MOVIE_TITLE              PRODUCTION_YEAR
# 1       4642044  Riot                     2015                                                        Action
# 2       1925518  The Protector 2          2013                                                        Action
# 3       372784   Batman Begins            2005                                              Action|Adventure
# 4       1390411  In the Heart of the Sea  2015             Action|Adventure|Biography|Drama|History|Thriller
# 5       6306064  Adrift                   2018             Action|Adventure|Biography|Drama|Romance|Thriller
# ...                                                                                                      ...
# 496     1846589  Hunter Killer            2018                                               Action|Thriller
# ...

# %%
# reset column index with example of missing index

# %%
df.reset_index(inplace=True)
df
# Out:
#      USER_ID  MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR  \
# 0          1   4642044                     Riot              2015
# 1          2   1925518          The Protector 2              2013
# 2          3    372784            Batman Begins              2005
# 3          4   1390411  In the Heart of the Sea              2015
# 4          5   6306064                   Adrift              2018
# ..       ...       ...                       ...              ...
# 495      496   1846589            Hunter Killer              2018
# 496      497   4196776             Jason Bourne              2016
# 497      498   7456310                     Anna              2019
# 498      499   8106534            6 Underground              2019
# 499      500   2302755       Olympus Has Fallen              2013
#
#                                                 GENRES  RATING  Unnamed: 6  \
# 0                                               Action     8.0         NaN
# ...

# %% [markdown]
# # sort index

# %%
df = pd.read_csv(path,index_col=["PRODUCTION_YEAR"])
df
# Out:
#                  USER_ID  MOVIE_ID               MOVIE_TITLE  \
# PRODUCTION_YEAR
# 2015                   1   4642044                     Riot
# 2013                   2   1925518          The Protector 2
# 2005                   3    372784            Batman Begins
# 2015                   4   1390411  In the Heart of the Sea
# 2018                   5   6306064                   Adrift
# ...                  ...       ...                       ...
# 2018                 496   1846589            Hunter Killer
# 2016                 497   4196776             Jason Bourne
# 2019                 498   7456310                     Anna
# 2019                 499   8106534            6 Underground
# 2013                 500   2302755       Olympus Has Fallen
#
#                                                             GENRES  RATING  \
# PRODUCTION_YEAR
# 2015                                                        Action     8.0
# ...

# %%
df.sort_index()
# Out:
#                  USER_ID  MOVIE_ID                       MOVIE_TITLE  \
# PRODUCTION_YEAR
# 1967                 255     61418                 Bonnie and Clyde
# 1969                 236     64757  On Her Majesty's Secret Service
# 1972                 365     69121                        Prime Cut
# 1973                 484     70909                        Westworld
# 1974                 237     71807      The Man with the Golden Gun
# ...                  ...       ...                               ...
# 2019                 206   4154664                   Captain Marvel
# 2019                 208   6565702                     Dark Phoenix
# 2019                 211   4154664                   Captain Marvel
# 2019                 156   6565702                     Dark Phoenix
# 2019                 142   5886046                      Escape Room
#
#                                                    GENRES  RATING  Unnamed: 6  \
# PRODUCTION_YEAR
# ...

# %%
df.sort_index(ascending=False,inplace=True)
df
# Out:
#                  USER_ID  MOVIE_ID                       MOVIE_TITLE  \
# PRODUCTION_YEAR
# 2019                 142   5886046                      Escape Room
# 2019                 208   6565702                     Dark Phoenix
# 2019                  30    448115                          Shazam!
# 2019                 426   1025100                       Gemini Man
# 2019                  33    448115                          Shazam!
# ...                  ...       ...                               ...
# 1974                 237     71807      The Man with the Golden Gun
# 1973                 484     70909                        Westworld
# 1972                 365     69121                        Prime Cut
# 1969                 236     64757  On Her Majesty's Secret Service
# 1967                 255     61418                 Bonnie and Clyde
#
#                                                    GENRES  RATING  Unnamed: 6  \
# PRODUCTION_YEAR
# ...

# %% [markdown]
# # header

# %%
df = pd.read_csv(r"C:/Users/baps/OneDrive/Desktop/Coding_Cloud/2. Python libraries/2) Pandas/Dataset/Movieratingdata5.csv")
df
# Out:
#            1         2                         3                4  \
# 0    USER_ID  MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR
# 1          1   4642044                     Riot              2015
# 2          2   1925518          The Protector 2              2013
# 3          3    372784            Batman Begins              2005
# 4          4   1390411  In the Heart of the Sea              2015
# ..       ...       ...                       ...              ...
# 496      496   1846589            Hunter Killer              2018
# 497      497   4196776             Jason Bourne              2016
# 498      498   7456310                     Anna              2019
# 499      499   8106534            6 Underground              2019
# 500      500   2302755       Olympus Has Fallen              2013
#
#                                                      5       6   7    8  \
# 0                                               GENRES  RATING NaN  NaN
# ...

# %%
df = pd.read_csv(r"C:/Users/baps/OneDrive/Desktop/Coding_Cloud/2. Python libraries/2) Pandas/Dataset/Movieratingdata5.csv",header=1)
df
# Out:
#      USER_ID  MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR  \
# 0          1   4642044                     Riot              2015
# 1          2   1925518          The Protector 2              2013
# 2          3    372784            Batman Begins              2005
# 3          4   1390411  In the Heart of the Sea              2015
# 4          5   6306064                   Adrift              2018
# ..       ...       ...                       ...              ...
# 495      496   1846589            Hunter Killer              2018
# 496      497   4196776             Jason Bourne              2016
# 497      498   7456310                     Anna              2019
# 498      499   8106534            6 Underground              2019
# 499      500   2302755       Olympus Has Fallen              2013
#
#                                                 GENRES  RATING  Unnamed: 6  \
# 0                                               Action     8.0         NaN
# ...

# %%
df1 = pd.read_csv(r"C:/Users/baps/OneDrive/Desktop/Coding_Cloud/2. Python libraries/2) Pandas/Dataset/Movieratingdata6.csv")
df1
# Out:
#        1  4642044                     Riot   2015  \
# 0      2  1925518          The Protector 2   2013
# 1      3   372784            Batman Begins   2005
# 2      4  1390411  In the Heart of the Sea   2015
# 3      5  6306064                   Adrift   2018
# 4      6  6306064                   Adrift   2018
# ..   ...      ...                       ...   ...
# 494  496  1846589            Hunter Killer   2018
# 495  497  4196776             Jason Bourne   2016
# 496  498  7456310                     Anna   2019
# 497  499  8106534            6 Underground   2019
# 498  500  2302755       Olympus Has Fallen   2013
#
#                                                 Action    8  Unnamed: 6  1.1  \
# 0                                               Action  5.0         NaN  5.0
# 1                                     Action|Adventure  9.0         NaN  NaN
# 2    Action|Adventure|Biography|Drama|History|Thriller  5.0         NaN  NaN
# ...

# %%
df1 = pd.read_csv(r"C:/Users/baps/OneDrive/Desktop/Coding_Cloud/2. Python libraries/2) Pandas/Dataset/Movieratingdata6.csv",header=None)
df1
# Out:
#        0        1                         2     3  \
# 0      1  4642044                     Riot   2015
# 1      2  1925518          The Protector 2   2013
# 2      3   372784            Batman Begins   2005
# 3      4  1390411  In the Heart of the Sea   2015
# 4      5  6306064                   Adrift   2018
# ..   ...      ...                       ...   ...
# 495  496  1846589            Hunter Killer   2018
# 496  497  4196776             Jason Bourne   2016
# 497  498  7456310                     Anna   2019
# 498  499  8106534            6 Underground   2019
# 499  500  2302755       Olympus Has Fallen   2013
#
#                                                      4    5   6    7  \
# 0                                               Action  8.0 NaN  1.0
# 1                                               Action  5.0 NaN  5.0
# 2                                     Action|Adventure  9.0 NaN  NaN
# 3    Action|Adventure|Biography|Drama|History|Thriller  5.0 NaN  NaN
# ...

# %%
df1 = pd.read_csv(r"C:/Users/baps/OneDrive/Desktop/Coding_Cloud/2. Python libraries/2) Pandas/Dataset/Movieratingdata6.csv", header=None)
df1 = df1.add_prefix("Data")
# Out:
# C:\Users\baps\AppData\Local\Temp\ipykernel_4668\3412988388.py:1: FutureWarning: The prefix argument has been deprecated and will be removed in a future version. Use a list comprehension on the column names in the future.
#
#
#   df1 = pd.read_csv(r"C:/Users/baps/OneDrive/Desktop/Coding_Cloud/2. Python libraries/2) Pandas/Dataset/Movieratingdata6.csv",header=None,prefix="Data")
#      Data0    Data1                     Data2  Data3  \
# 0        1  4642044                     Riot    2015
# 1        2  1925518          The Protector 2    2013
# 2        3   372784            Batman Begins    2005
# 3        4  1390411  In the Heart of the Sea    2015
# 4        5  6306064                   Adrift    2018
# ..     ...      ...                       ...    ...
# 495    496  1846589            Hunter Killer    2018
# 496    497  4196776             Jason Bourne    2016
# 497    498  7456310                     Anna    2019
# 498    499  8106534            6 Underground    2019
# ...

# %%
df1 = pd.read_csv(r"C:/Users/baps/OneDrive/Desktop/Coding_Cloud/2. Python libraries/2) Pandas/Dataset/Movieratingdata6.csv",names=["A","B","C","D","E","F","G","H","I","J"])
df1
# Out:
#        A        B                         C     D  \
# 0      1  4642044                     Riot   2015
# 1      2  1925518          The Protector 2   2013
# 2      3   372784            Batman Begins   2005
# 3      4  1390411  In the Heart of the Sea   2015
# 4      5  6306064                   Adrift   2018
# ..   ...      ...                       ...   ...
# 495  496  1846589            Hunter Killer   2018
# 496  497  4196776             Jason Bourne   2016
# 497  498  7456310                     Anna   2019
# 498  499  8106534            6 Underground   2019
# 499  500  2302755       Olympus Has Fallen   2013
#
#                                                      E    F   G    H  \
# 0                                               Action  8.0 NaN  1.0
# 1                                               Action  5.0 NaN  5.0
# 2                                     Action|Adventure  9.0 NaN  NaN
# 3    Action|Adventure|Biography|Drama|History|Thriller  5.0 NaN  NaN
# ...

# %% [markdown]
# # head and tail

# %%
df = pd.read_csv(path)
df
# Out:
#      USER_ID  MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR  \
# 0          1   4642044                     Riot              2015
# 1          2   1925518          The Protector 2              2013
# 2          3    372784            Batman Begins              2005
# 3          4   1390411  In the Heart of the Sea              2015
# 4          5   6306064                   Adrift              2018
# ..       ...       ...                       ...              ...
# 495      496   1846589            Hunter Killer              2018
# 496      497   4196776             Jason Bourne              2016
# 497      498   7456310                     Anna              2019
# 498      499   8106534            6 Underground              2019
# 499      500   2302755       Olympus Has Fallen              2013
#
#                                                 GENRES  RATING  Unnamed: 6  \
# 0                                               Action     8.0         NaN
# ...

# %%
df.head()
# Out:
#    USER_ID  MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR  \
# 0        1   4642044                     Riot              2015
# 1        2   1925518          The Protector 2              2013
# 2        3    372784            Batman Begins              2005
# 3        4   1390411  In the Heart of the Sea              2015
# 4        5   6306064                   Adrift              2018
#
#                                               GENRES  RATING  Unnamed: 6  \
# 0                                             Action     8.0         NaN
# 1                                             Action     5.0         NaN
# 2                                   Action|Adventure     9.0         NaN
# 3  Action|Adventure|Biography|Drama|History|Thriller     5.0         NaN
# 4  Action|Adventure|Biography|Drama|Romance|Thriller     4.0         NaN
#
#    Unnamed: 7    GENRES.1  Unnamed: 9
# 0         1.0      action         8.0
# 1         5.0    suspense         6.0
# ...

# %%
df.head(10)       #max is 60
# Out:
#    USER_ID  MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR  \
# 0        1   4642044                     Riot              2015
# 1        2   1925518          The Protector 2              2013
# 2        3    372784            Batman Begins              2005
# 3        4   1390411  In the Heart of the Sea              2015
# 4        5   6306064                   Adrift              2018
# 5        6   6306064                   Adrift              2018
# 6        7   2719848                  Everest              2015
# 7        8    462504              Rescue Dawn              2006
# 8        9   1663202             The Revenant              2015
# 9       10   1663202             The Revenant              2015
#
#                                               GENRES  RATING  Unnamed: 6  \
# 0                                             Action     8.0         NaN
# 1                                             Action     5.0         NaN
# ...

# %%
df.tail()
# Out:
#      USER_ID  MOVIE_ID          MOVIE_TITLE  PRODUCTION_YEAR           GENRES  \
# 495      496   1846589       Hunter Killer              2018  Action|Thriller
# 496      497   4196776        Jason Bourne              2016  Action|Thriller
# 497      498   7456310                Anna              2019  Action|Thriller
# 498      499   8106534       6 Underground              2019  Action|Thriller
# 499      500   2302755  Olympus Has Fallen              2013  Action|Thriller
#
#      RATING  Unnamed: 6  Unnamed: 7 GENRES.1  Unnamed: 9
# 495     6.0         NaN         NaN      NaN         NaN
# 496     6.0         NaN         NaN      NaN         NaN
# 497     7.0         NaN         NaN      NaN         NaN
# 498     4.0         NaN         NaN      NaN         NaN
# 499     1.0         NaN         NaN      NaN         NaN

# %%
df.tail(7)     #max is 60
# Out:
#      USER_ID  MOVIE_ID              MOVIE_TITLE  PRODUCTION_YEAR  \
# 493      494   1606378  A Good Day to Die Hard              2013
# 494      495   1781922               No Escape              2015
# 495      496   1846589           Hunter Killer              2018
# 496      497   4196776            Jason Bourne              2016
# 497      498   7456310                    Anna              2019
# 498      499   8106534           6 Underground              2019
# 499      500   2302755      Olympus Has Fallen              2013
#
#               GENRES  RATING  Unnamed: 6  Unnamed: 7 GENRES.1  Unnamed: 9
# 493  Action|Thriller     5.0         NaN         NaN      NaN         NaN
# 494  Action|Thriller     7.0         NaN         NaN      NaN         NaN
# 495  Action|Thriller     6.0         NaN         NaN      NaN         NaN
# 496  Action|Thriller     6.0         NaN         NaN      NaN         NaN
# 497  Action|Thriller     7.0         NaN         NaN      NaN         NaN
# ...

# %% [markdown]
# # info,describe,shape(with its option),size,sample

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   USER_ID          500 non-null    int64
#  1   MOVIE_ID         500 non-null    int64
#  2   MOVIE_TITLE      500 non-null    object
#  3   PRODUCTION_YEAR  500 non-null    int64
#  4   GENRES           500 non-null    object
#  5   RATING           500 non-null    float64
#  6   Unnamed: 6       0 non-null      float64
#  7   Unnamed: 7       2 non-null      float64
#  8   GENRES.1         5 non-null      object
#  9   Unnamed: 9       4 non-null      float64
# dtypes: float64(4), int64(3), object(3)
# memory usage: 39.2+ KB

# %%
df.describe()
# Out:
#           USER_ID      MOVIE_ID  PRODUCTION_YEAR      RATING  Unnamed: 6  \
# count  500.000000  5.000000e+02       500.000000  500.000000         0.0
# mean   250.500000  2.082635e+06      2012.134000    7.046400         NaN
# std    144.481833  1.677033e+06         8.629077    1.584471         NaN
# min      1.000000  6.141800e+04      1967.000000    1.000000         NaN
# 25%    125.750000  1.012145e+06      2013.000000    6.000000         NaN
# 50%    250.500000  1.663202e+06      2015.000000    7.000000         NaN
# 75%    375.250000  2.713180e+06      2017.000000    8.000000         NaN
# max    500.000000  9.541602e+06      2019.000000   10.000000         NaN
#
#        Unnamed: 7  Unnamed: 9
# count    2.000000    4.000000
# mean     3.000000    5.750000
# std      2.828427    1.707825
# min      1.000000    4.000000
# 25%      2.000000    4.750000
# 50%      3.000000    5.500000
# 75%      4.000000    6.500000
# max      5.000000    8.000000

# %%
df.shape
# Out:
# (500, 10)

# %%
df.shape[0]
# Out:
# 500

# %%
df.shape[1]
# Out:
# 10

# %%
df.size
# Out:
# 5000

# %%
df.sample()
# Out:
#      USER_ID  MOVIE_ID MOVIE_TITLE  PRODUCTION_YEAR  \
# 456      457   4779682    The Meg              2018
#
#                             GENRES  RATING  Unnamed: 6  Unnamed: 7 GENRES.1  \
# 456  Action|Horror|Sci-Fi|Thriller     6.0         NaN         NaN      NaN
#
#      Unnamed: 9
# 456         NaN

# %% [markdown]
# # access in column with loc and iloc

# %%
#loc

# %%
df.loc[0]
# Out:
# USER_ID                  1
# MOVIE_ID           4642044
# MOVIE_TITLE          Riot
# PRODUCTION_YEAR       2015
# GENRES              Action
# RATING                 8.0
# Unnamed: 6             NaN
# Unnamed: 7             1.0
# GENRES.1            action
# Unnamed: 9             8.0
# Name: 0, dtype: object

# %%
df.loc[[5,1,8]]
# Out:
#    USER_ID  MOVIE_ID       MOVIE_TITLE  PRODUCTION_YEAR  \
# 5        6   6306064           Adrift              2018
# 1        2   1925518  The Protector 2              2013
# 8        9   1663202     The Revenant              2015
#
#                                               GENRES  RATING  Unnamed: 6  \
# 5  Action|Adventure|Biography|Drama|Romance|Thriller     5.0         NaN
# 1                                             Action     5.0         NaN
# 8           Action|Adventure|Biography|Drama|Western    10.0         NaN
#
#    Unnamed: 7  GENRES.1  Unnamed: 9
# 5         NaN       NaN         NaN
# 1         5.0  suspense         6.0
# 8         NaN       NaN         NaN

# %%
df.loc[5,"MOVIE_TITLE"]
# Out:
# 'Adrift '

# %%
df.loc[1:10,"MOVIE_TITLE"]
# Out:
# 1             The Protector 2
# 2               Batman Begins
# 3     In the Heart of the Sea
# 4                      Adrift
# 5                      Adrift
# 6                     Everest
# 7                 Rescue Dawn
# 8                The Revenant
# 9                The Revenant
# 10               The Revenant
# Name: MOVIE_TITLE, dtype: object

# %%
df.loc[1:10,["MOVIE_ID","MOVIE_TITLE","PRODUCTION_YEAR","GENRES","RATING"]]
# Out:
#     MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR  \
# 1    1925518          The Protector 2              2013
# 2     372784            Batman Begins              2005
# 3    1390411  In the Heart of the Sea              2015
# 4    6306064                   Adrift              2018
# 5    6306064                   Adrift              2018
# 6    2719848                  Everest              2015
# 7     462504              Rescue Dawn              2006
# 8    1663202             The Revenant              2015
# 9    1663202             The Revenant              2015
# 10   1663202             The Revenant              2015
#
#                                                GENRES  RATING
# 1                                              Action     5.0
# 2                                    Action|Adventure     9.0
# 3   Action|Adventure|Biography|Drama|History|Thriller     5.0
# 4   Action|Adventure|Biography|Drama|Romance|Thriller     4.0
# ...

# %%
x = df.loc[:,["MOVIE_ID","MOVIE_TITLE","PRODUCTION_YEAR","GENRES","RATING"]]
x
# Out:
#      MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR  \
# 0     4642044                     Riot              2015
# 1     1925518          The Protector 2              2013
# 2      372784            Batman Begins              2005
# 3     1390411  In the Heart of the Sea              2015
# 4     6306064                   Adrift              2018
# ..        ...                       ...              ...
# 495   1846589            Hunter Killer              2018
# 496   4196776             Jason Bourne              2016
# 497   7456310                     Anna              2019
# 498   8106534            6 Underground              2019
# 499   2302755       Olympus Has Fallen              2013
#
#                                                 GENRES  RATING
# 0                                               Action     8.0
# 1                                               Action     5.0
# 2                                     Action|Adventure     9.0
# ...

# %%
#iloc

# %%
df.iloc[0]
# Out:
# USER_ID                  1
# MOVIE_ID           4642044
# MOVIE_TITLE          Riot
# PRODUCTION_YEAR       2015
# GENRES              Action
# RATING                 8.0
# Unnamed: 6             NaN
# Unnamed: 7             1.0
# GENRES.1            action
# Unnamed: 9             8.0
# Name: 0, dtype: object

# %%
df.iloc[[0]]
# Out:
#    USER_ID  MOVIE_ID MOVIE_TITLE  PRODUCTION_YEAR  GENRES  RATING  Unnamed: 6  \
# 0        1   4642044       Riot              2015  Action     8.0         NaN
#
#    Unnamed: 7 GENRES.1  Unnamed: 9
# 0         1.0   action         8.0

# %%
df.iloc[[0,1]]
# Out:
#    USER_ID  MOVIE_ID       MOVIE_TITLE  PRODUCTION_YEAR  GENRES  RATING  \
# 0        1   4642044             Riot              2015  Action     8.0
# 1        2   1925518  The Protector 2              2013  Action     5.0
#
#    Unnamed: 6  Unnamed: 7  GENRES.1  Unnamed: 9
# 0         NaN         1.0    action         8.0
# 1         NaN         5.0  suspense         6.0

# %%
df.iloc[:,0]   # only in iloc
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 495    496
# 496    497
# 497    498
# 498    499
# 499    500
# Name: USER_ID, Length: 500, dtype: int64

# %%
df.iloc[0:11,0:6]
# Out:
#     USER_ID  MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR  \
# 0         1   4642044                     Riot              2015
# 1         2   1925518          The Protector 2              2013
# 2         3    372784            Batman Begins              2005
# 3         4   1390411  In the Heart of the Sea              2015
# 4         5   6306064                   Adrift              2018
# 5         6   6306064                   Adrift              2018
# 6         7   2719848                  Everest              2015
# 7         8    462504              Rescue Dawn              2006
# 8         9   1663202             The Revenant              2015
# 9        10   1663202             The Revenant              2015
# 10       11   1663202             The Revenant              2015
#
#                                                GENRES  RATING
# 0                                              Action     8.0
# ...

# %%
df.iloc[0,2]="Roit 2"
df
# Out:
#      USER_ID  MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR  \
# 0          1   4642044                    Roit 2             2015
# 1          2   1925518          The Protector 2              2013
# 2          3    372784            Batman Begins              2005
# 3          4   1390411  In the Heart of the Sea              2015
# 4          5   6306064                   Adrift              2018
# ..       ...       ...                       ...              ...
# 495      496   1846589            Hunter Killer              2018
# 496      497   4196776             Jason Bourne              2016
# 497      498   7456310                     Anna              2019
# 498      499   8106534            6 Underground              2019
# 499      500   2302755       Olympus Has Fallen              2013
#
#                                                 GENRES  RATING  Unnamed: 6  \
# 0                                               Action     8.0         NaN
# ...

# %%
df.iloc[8:15,[1,7,3]]
# Out:
#     MOVIE_ID  Unnamed: 7  PRODUCTION_YEAR
# 8    1663202         NaN             2015
# 9    1663202         NaN             2015
# 10   1663202         NaN             2015
# 11   1663202         NaN             2015
# 12   1663202         NaN             2015
# 13   1663202         NaN             2015
# 14   1663202         NaN             2015

# %%
df.iloc[8:35:3,::2]
# Out:
#     USER_ID               MOVIE_TITLE  \
# 8         9             The Revenant
# 11       12             The Revenant
# 14       15             The Revenant
# 17       18  The Man from U.N.C.L.E.
# 20       21  The Man from U.N.C.L.E.
# 23       24         Now You See Me 2
# 26       27                  Grimsby
# 29       30                  Shazam!
# 32       33                  Shazam!
#
#                                             GENRES  Unnamed: 6 GENRES.1
# 8         Action|Adventure|Biography|Drama|Western         NaN      NaN
# 11        Action|Adventure|Biography|Drama|Western         NaN      NaN
# 14        Action|Adventure|Biography|Drama|Western         NaN      NaN
# 17                         Action|Adventure|Comedy         NaN      NaN
# 20                         Action|Adventure|Comedy         NaN      NaN
# 23  Action|Adventure|Comedy|Crime|Mystery|Thriller         NaN      NaN
# 26          Action|Adventure|Comedy|Crime|Thriller         NaN      NaN
# ...

# %% [markdown]
# # set_option for rows and column

# %%
# pd.set_option("display.max_rows",500)
# pd.set_option("display.max_rows",None) 
# pd.set_option("display.min_rows",5)
# pd.set_option("display.max_column",6)
# pd.set_option("display.max_colwidth",None)
# pd.reset_option("display.max_colwidth")
# pd.reset_option("display.width")

# %%
df = pd.read_csv(path)
df
# Out:
#      USER_ID  MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR  \
# 0          1   4642044                     Riot              2015
# 1          2   1925518          The Protector 2              2013
# 2          3    372784            Batman Begins              2005
# 3          4   1390411  In the Heart of the Sea              2015
# 4          5   6306064                   Adrift              2018
# ..       ...       ...                       ...              ...
# 495      496   1846589            Hunter Killer              2018
# 496      497   4196776             Jason Bourne              2016
# 497      498   7456310                     Anna              2019
# 498      499   8106534            6 Underground              2019
# 499      500   2302755       Olympus Has Fallen              2013
#
#                                                 GENRES  RATING  Unnamed: 6  \
# 0                                               Action     8.0         NaN
# ...
