# %%
import pandas as pd

# %%
df = pd.read_csv(r"Dataset/survey_results_public.csv")
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
india = df[df["Country"]=="India"]
india
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 7               8             I code primarily as a hobby      Yes
# 9              10          I am a developer by profession      Yes
# 14             15  I am a student who is learning to code      Yes
# 49             50          I am a developer by profession      Yes
# 64             65          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 88808       77339                                     NaN      Yes
# 88825       79795                                     NaN      Yes
# 88852       83862                                     NaN      Yes
# 88853       84299                                     NaN      Yes
# 88864       86012                                     NaN      Yes
#
#                                              OpenSourcer  \
# 7                                Less than once per year
# ...

# %%
india.to_csv(r"india_python.csv")

# %% [markdown]
# # excel

# %%
# this will install excel

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# for read excel

# %%
pip install xlrd
# Out:
# ...
#      -------------------------------------- 96.5/96.5 kB 918.0 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# for write excel

# %%
pip install xlwt
# Out:
# ...
#      -------------------------------------- 100.0/100.0 kB 1.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
sells = pd.read_excel(r"Dataset/Super Store Sales data.xls")
sells
# Out:
#        Row ID       Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  IN-2013-27828 2013-08-26 2013-08-30  Standard Class
# 1           2  IN-2013-27828 2013-08-26 2013-08-30  Standard Class
# 2           3  IN-2013-27828 2013-08-26 2013-08-30  Standard Class
# 3           4  IN-2013-27828 2013-08-26 2013-08-30  Standard Class
# 4           5  IN-2014-63178 2014-06-24 2014-06-30  Standard Class
# ...       ...            ...        ...        ...             ...
# 10995   10996  IN-2013-82673 2013-09-10 2013-09-14  Standard Class
# 10996   10997  IN-2013-82673 2013-09-10 2013-09-14  Standard Class
# 10997   10998  IN-2013-82673 2013-09-10 2013-09-14  Standard Class
# 10998   10999  ID-2012-83604 2012-08-28 2012-08-28        Same Day
# 10999   11000  ID-2012-83604 2012-08-28 2012-08-28        Same Day
#
#       Customer ID     Customer Name      Segment        City  \
# 0        VT-21700  Valerie Takahito  Home Office     Luoyang
# ...

# %%
China = sells[sells["Country"]=="China"]
China
# Out:
#       Row ID       Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0          1  IN-2013-27828 2013-08-26 2013-08-30  Standard Class    VT-21700
# 1          2  IN-2013-27828 2013-08-26 2013-08-30  Standard Class    VT-21700
# 2          3  IN-2013-27828 2013-08-26 2013-08-30  Standard Class    VT-21700
# 3          4  IN-2013-27828 2013-08-26 2013-08-30  Standard Class    VT-21700
# 22        23  ID-2014-64914 2014-03-27 2014-03-28     First Class    AS-10285
# ...      ...            ...        ...        ...             ...         ...
# 9972    9973  ID-2012-66111 2012-06-14 2012-06-17     First Class    AB-10015
# 9984    9985  IN-2012-40813 2012-12-07 2012-12-11    Second Class    CA-11965
# 9985    9986  IN-2012-40813 2012-12-07 2012-12-11    Second Class    CA-11965
# 9986    9987  IN-2012-40813 2012-12-07 2012-12-11    Second Class    CA-11965
# 9996    9997  IN-2011-33771 2011-06-28 2011-07-02  Standard Class    SC-20440
#
# ...

# %%
China.to_excel(r"Dataset/china.xlsx")

# %% [markdown]
# # json

# %%
df = pd.read_csv(r"Dataset/survey_results_public.csv")

# %%
df.to_json(r"C:/Users/baps/OneDrive/Desktop/Coding_Cloud/2. Python libraries/file.json")

# %%
file = pd.read_json(r"C:/Users/baps/OneDrive/Desktop/Coding_Cloud/2. Python libraries/file.json")
file
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                               None      Yes
# 88879       88601                                               None       No
# 88880       88802                                               None       No
# 88881       88816                                               None       No
# 88882       88863                                               None      Yes
#
# ...

# %%
df.to_json(r"C:/Users/baps/OneDrive/Desktop/Coding_Cloud/2. Python libraries/file1.json",orient="index")

# %%
file1 = pd.read_json(r"C:/Users/baps/OneDrive/Desktop/Coding_Cloud/2. Python libraries/file1.json")
file1
# Out:
#                                                           0      \
# Respondent                                                    1
# MainBranch               I am a student who is learning to code
# Hobbyist                                                    Yes
# OpenSourcer                                               Never
# OpenSource    The quality of OSS and closed source software ...
# ...                                                         ...
# Sexuality                               Straight / Heterosexual
# Ethnicity                                                  None
# Dependents                                                   No
# SurveyLength                              Appropriate in length
# SurveyEase                           Neither easy nor difficult
#
#                                                           1      \
# Respondent                                                    2
# MainBranch               I am a student who is learning to code
# ...

# %%
import pandas as pd
import os

df = (r"Dataset/survey_results_public.csv")

# Path to Downloads folder
df = os.path.expanduser(r"C:\Users\Dell\Downloads")

# Save file
df.to_csv(f"{df}/cleaned_file.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 10
#       7 df = os.path.expanduser(r"C:\Users\Dell\Downloads")
#       9 # Save file
# ---> 10 df.to_csv(f"{df}/cleaned_file.csv", index=False)
#
# AttributeError: 'str' object has no attribute 'to_csv'
