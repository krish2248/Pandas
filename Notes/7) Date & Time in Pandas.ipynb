# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Pivot Table

# %%
df = pd.read_csv(r"D:\python lerning\Dataset\Movieratingdata8.csv")
df
# Out:
#        Genre  Year  Budget(M$)  Rating %
# 0     Action  2008          28        48
# 1     Action  2009         200        63
# 2     Action  2008          32        57
# 3     Action  2010          20        52
# 4  Adventure  2009          18        84
# 5  Adventure  2010         105        44
# 6     Comedy  2010          20        70
# 7     Comedy  2008           8        81
# 8     Comedy  2009          30        71

# %%
df.pivot_table(index="Genre")
# Out:
#            Budget(M$)  Rating %     Year
# Genre
# Action      70.000000      55.0  2008.75
# Adventure   61.500000      64.0  2009.50
# Comedy      19.333333      74.0  2009.00

# %%
df.pivot_table(index="Genre",columns="Year")
# Out:
#           Budget(M$)               Rating %
# Year            2008   2009   2010     2008  2009  2010
# Genre
# Action          30.0  200.0   20.0     52.5  63.0  52.0
# Adventure        NaN   18.0  105.0      NaN  84.0  44.0
# Comedy           8.0   30.0   20.0     81.0  71.0  70.0

# %%
df.pivot_table(index="Genre",columns="Year",aggfunc="max")   # max,sum,count,min,mean
# Out:
#           Budget(M$)               Rating %
# Year            2008   2009   2010     2008  2009  2010
# Genre
# Action          32.0  200.0   20.0     57.0  63.0  52.0
# Adventure        NaN   18.0  105.0      NaN  84.0  44.0
# Comedy           8.0   30.0   20.0     81.0  71.0  70.0

# %%
df.pivot_table(index="Genre",columns="Year",fill_value=0)
# Out:
#           Budget(M$)               Rating %
# Year            2008   2009   2010     2008  2009  2010
# Genre
# Action          30.0  200.0   20.0     52.5  63.0  52.0
# Adventure        0.0   18.0  105.0      0.0  84.0  44.0
# Comedy           8.0   30.0   20.0     81.0  71.0  70.0

# %%
df.pivot_table(index="Genre",columns="Year",fill_value=0,margins=True)
# Out:
#           Budget(M$)                                    Rating %             \
# Year            2008        2009        2010        All     2008       2009
# Genre
# Action     30.000000  200.000000   20.000000  70.000000     52.5  63.000000
# Adventure   0.000000   18.000000  105.000000  61.500000      0.0  84.000000
# Comedy      8.000000   30.000000   20.000000  19.333333     81.0  71.000000
# All        22.666667   82.666667   48.333333  51.222222     62.0  72.666667
#
#
# Year            2010        All
# Genre
# Action     52.000000  55.000000
# Adventure  44.000000  64.000000
# Comedy     70.000000  74.000000
# All        55.333333  63.333333

# %%
df.pivot_table(index="Genre",columns="Year",aggfunc="sum",fill_value=0,margins=True)
# Out:
#           Budget(M$)                Rating %
# Year            2008 2009 2010  All     2008 2009 2010  All
# Genre
# Action            60  200   20  280      105   63   52  220
# Adventure          0   18  105  123        0   84   44  128
# Comedy             8   30   20   58       81   71   70  222
# All               68  248  145  461      186  218  166  570

# %% [markdown]
# # Melt Function

# %% [raw]
# * used to transform or reshape data.

# %%
df = pd.read_csv(r"D:\python lerning\Dataset\Movieratingdata8.csv")
df
# Out:
#        Genre  Year  Budget(M$)  Rating %
# 0     Action  2008          28        48
# 1     Action  2009         200        63
# 2     Action  2008          32        57
# 3     Action  2010          20        52
# 4  Adventure  2009          18        84
# 5  Adventure  2010         105        44
# 6     Comedy  2010          20        70
# 7     Comedy  2008           8        81
# 8     Comedy  2009          30        71

# %%
pd.melt(df)
# Out:
#       variable      value
# 0        Genre     Action
# 1        Genre     Action
# 2        Genre     Action
# 3        Genre     Action
# 4        Genre  Adventure
# 5        Genre  Adventure
# 6        Genre     Comedy
# 7        Genre     Comedy
# 8        Genre     Comedy
# 9         Year       2008
# 10        Year       2009
# 11        Year       2008
# 12        Year       2010
# 13        Year       2009
# 14        Year       2010
# 15        Year       2010
# 16        Year       2008
# 17        Year       2009
# 18  Budget(M$)         28
# 19  Budget(M$)        200
# 20  Budget(M$)         32
# 21  Budget(M$)         20
# 22  Budget(M$)         18
# 23  Budget(M$)        105
# 24  Budget(M$)         20
# 25  Budget(M$)          8
# 26  Budget(M$)         30
# 27    Rating %         48
# 28    Rating %         63
# 29    Rating %         57
# 30    Rating %         52
# 31    Rating %         84
# 32    Rating %         44
# 33    Rating %         70
# ...

# %%
pd.melt(df,id_vars=["Year"])
# Out:
#     Year    variable      value
# 0   2008       Genre     Action
# 1   2009       Genre     Action
# 2   2008       Genre     Action
# 3   2010       Genre     Action
# 4   2009       Genre  Adventure
# 5   2010       Genre  Adventure
# 6   2010       Genre     Comedy
# 7   2008       Genre     Comedy
# 8   2009       Genre     Comedy
# 9   2008  Budget(M$)         28
# 10  2009  Budget(M$)        200
# 11  2008  Budget(M$)         32
# 12  2010  Budget(M$)         20
# 13  2009  Budget(M$)         18
# 14  2010  Budget(M$)        105
# 15  2010  Budget(M$)         20
# 16  2008  Budget(M$)          8
# 17  2009  Budget(M$)         30
# 18  2008    Rating %         48
# 19  2009    Rating %         63
# 20  2008    Rating %         57
# 21  2010    Rating %         52
# 22  2009    Rating %         84
# 23  2010    Rating %         44
# 24  2010    Rating %         70
# 25  2008    Rating %         81
# 26  2009    Rating %         71

# %%
pd.melt(df,id_vars=["Year"],value_vars=["Genre"])
# Out:
#    Year variable      value
# 0  2008    Genre     Action
# 1  2009    Genre     Action
# 2  2008    Genre     Action
# 3  2010    Genre     Action
# 4  2009    Genre  Adventure
# 5  2010    Genre  Adventure
# 6  2010    Genre     Comedy
# 7  2008    Genre     Comedy
# 8  2009    Genre     Comedy

# %%
pd.melt(df,id_vars=["Year"],value_vars=["Genre"],var_name="Category")
# Out:
#    Year Category      value
# 0  2008    Genre     Action
# 1  2009    Genre     Action
# 2  2008    Genre     Action
# 3  2010    Genre     Action
# 4  2009    Genre  Adventure
# 5  2010    Genre  Adventure
# 6  2010    Genre     Comedy
# 7  2008    Genre     Comedy
# 8  2009    Genre     Comedy

# %%
pd.melt(df,id_vars=["Year"],value_vars=["Genre"],var_name="Category",value_name="Data")
# Out:
#    Year Category       Data
# 0  2008    Genre     Action
# 1  2009    Genre     Action
# 2  2008    Genre     Action
# 3  2010    Genre     Action
# 4  2009    Genre  Adventure
# 5  2010    Genre  Adventure
# 6  2010    Genre     Comedy
# 7  2008    Genre     Comedy
# 8  2009    Genre     Comedy

# %% [markdown]
# # Date & Time

# %%
data = {'date1':['2020-12-01','2020-12-03','2020-12-05','2020-12-06','2020-12-08'],
        'date2':['201201','201203','201205','201206','201208',],
        'store':['A','B','C','D','E'],
        'sales':[2000,3000,4000,5000,6000]}

# %%
df = pd.DataFrame(data)
df
# Out:
#         date1   date2 store  sales
# 0  2020-12-01  201201     A   2000
# 1  2020-12-03  201203     B   3000
# 2  2020-12-05  201205     C   4000
# 3  2020-12-06  201206     D   5000
# 4  2020-12-08  201208     E   6000

# %%
df.dtypes
# Out:
# date1    object
# date2    object
# store    object
# sales     int64
# dtype: object

# %% [markdown]
# # change data type of date1 with to_datetime

# %%
df['date1'] = pd.to_datetime(df['date1'])

# %%
df.dtypes
# Out:
# date1    datetime64[ns]
# date2            object
# store            object
# sales             int64
# dtype: object

# %% [markdown]
# # change data type of date with astype

# %%
df = pd.DataFrame(data)
df
# Out:
#         date1   date2 store  sales
# 0  2020-12-01  201201     A   2000
# 1  2020-12-03  201203     B   3000
# 2  2020-12-05  201205     C   4000
# 3  2020-12-06  201206     D   5000
# 4  2020-12-08  201208     E   6000

# %%
df.dtypes
# Out:
# date1    object
# date2    object
# store    object
# sales     int64
# dtype: object

# %% [markdown]
# # find day name

# %%
df['date1'].dt.day_name()
# Out:
# 0     Tuesday
# 1    Thursday
# 2    Saturday
# 3      Sunday
# 4     Tuesday
# Name: date1, dtype: object

# %%
df.loc[2,'date1'].day_name()
# Out:
# 'Saturday'

# %%
df.iloc[2,0].day_name()
# Out:
# 'Saturday'

# %% [markdown]
# # max date

# %%
df['date1'].max()
# Out:
# Timestamp('2020-12-08 00:00:00')

# %% [markdown]
# # min date

# %%
df['date1'].min()
# Out:
# Timestamp('2020-12-01 00:00:00')

# %% [markdown]
# # filter data with to date range

# %%
filt = df[(df['date1'] > pd.to_datetime('2020-12-1')) & (df['date1'] < pd.to_datetime('2020-12-8'))]
filt
# Out:
#        date1   date2 store  sales
# 1 2020-12-03  201203     B   3000
# 2 2020-12-05  201205     C   4000
# 3 2020-12-06  201206     D   5000

# %%
data2 = df[(df['date1'] > pd.to_datetime('2020-12-3'))]
data2
# Out:
#        date1   date2 store  sales
# 2 2020-12-05  201205     C   4000
# 3 2020-12-06  201206     D   5000
# 4 2020-12-08  201208     E   6000

# %% [markdown]
# # reading date in different fomate

# %%
df = pd.DataFrame(data)
df
# Out:
#         date1   date2 store  sales
# 0  2020-12-01  201201     A   2000
# 1  2020-12-03  201203     B   3000
# 2  2020-12-05  201205     C   4000
# 3  2020-12-06  201206     D   5000
# 4  2020-12-08  201208     E   6000

# %%
df['date2'] = pd.to_datetime(df['date2'])
df
# Out:
#         date1      date2 store  sales
# 0  2020-12-01 2001-12-20     A   2000
# 1  2020-12-03 2003-12-20     B   3000
# 2  2020-12-05 2005-12-20     C   4000
# 3  2020-12-06 2006-12-20     D   5000
# 4  2020-12-08 2008-12-20     E   6000

# %%
df.dtypes
# Out:
# date1            object
# date2    datetime64[ns]
# store            object
# sales             int64
# dtype: object

# %%
df = pd.DataFrame(data)
df['date2'] = pd.to_datetime(df['date2'],format="%y%m%d")     #format method we tell him how to read data.
df
# Out:
#         date1      date2 store  sales
# 0  2020-12-01 2020-12-01     A   2000
# 1  2020-12-03 2020-12-03     B   3000
# 2  2020-12-05 2020-12-05     C   4000
# 3  2020-12-06 2020-12-06     D   5000
# 4  2020-12-08 2020-12-08     E   6000

# %%
df = pd.DataFrame(data)
df['date2'] = pd.to_datetime(df['date2'],format="%d%m%y")
df
# Out:
#         date1      date2 store  sales
# 0  2020-12-01 2001-12-20     A   2000
# 1  2020-12-03 2003-12-20     B   3000
# 2  2020-12-05 2005-12-20     C   4000
# 3  2020-12-06 2006-12-20     D   5000
# 4  2020-12-08 2008-12-20     E   6000

# %%
df = pd.DataFrame(data)
df['date2'] = pd.to_datetime(df['date2'],format="%Y%m")
df
# Out:
#         date1      date2 store  sales
# 0  2020-12-01 2012-01-01     A   2000
# 1  2020-12-03 2012-03-01     B   3000
# 2  2020-12-05 2012-05-01     C   4000
# 3  2020-12-06 2012-06-01     D   5000
# 4  2020-12-08 2012-08-01     E   6000

# %% [markdown]
# # strf in pandas

# %%
import datetime as dt

# %%
df['date1'] = pd.to_datetime(df['date1'])

# %%
df['date1'] = df['date1'].dt.strftime("%d-%m-%y")
df
# Out:
#       date1      date2 store  sales
# 0  01-12-20 2012-01-01     A   2000
# 1  03-12-20 2012-03-01     B   3000
# 2  05-12-20 2012-05-01     C   4000
# 3  06-12-20 2012-06-01     D   5000
# 4  08-12-20 2012-08-01     E   6000

# %%
df.dtypes    # we can only change fromate of date1 column if it's formate is object
# Out:
# date1            object
# date2    datetime64[ns]
# store            object
# sales             int64
# dtype: object

# %%
df['date1'] = pd.to_datetime(df['date1'])
df
# Out:
#        date1      date2 store  sales
# 0 2020-01-12 2012-01-01     A   2000
# 1 2020-03-12 2012-03-01     B   3000
# 2 2020-05-12 2012-05-01     C   4000
# 3 2020-06-12 2012-06-01     D   5000
# 4 2020-08-12 2012-08-01     E   6000

# %%
df.dtypes    # we can not output shown in datafram of date if we want to keep its data type as datetime
# Out:
# date1    datetime64[ns]
# date2    datetime64[ns]
# store            object
# sales             int64
# dtype: object

# %% [markdown]
# # sorting data

# %%
df = pd.DataFrame(data)
df
# Out:
#         date1   date2 store  sales
# 0  2020-12-01  201201     A   2000
# 1  2020-12-03  201203     B   3000
# 2  2020-12-05  201205     C   4000
# 3  2020-12-06  201206     D   5000
# 4  2020-12-08  201208     E   6000

# %%
df['date1'] = pd.to_datetime(df['date1'])

# %%
df.sort_values(by='date1',ascending=False,inplace=True)
df
# Out:
#        date1   date2 store  sales
# 4 2020-12-08  201208     E   6000
# 3 2020-12-06  201206     D   5000
# 2 2020-12-05  201205     C   4000
# 1 2020-12-03  201203     B   3000
# 0 2020-12-01  201201     A   2000
