# %%
import pandas as pd
import numpy as np

# %pip install kagglehub
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Users\sonik\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
path = r"C:\Users\sonik\Desktop\survey_results_public.csv"

df = pd.read_csv(path)
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df.sort_values(['Age1stCode'])
# Out:
#        Respondent                              MainBranch Hobbyist   Age  \
# 32574       32694  I am a student who is learning to code      Yes  19.0
# 53085       54173          I am a developer by profession       No  25.0
# 25389       25483          I am a developer by profession      Yes  22.0
# 2683         2696          I am a developer by profession       No   NaN
# 53081       54169          I am a developer by profession      Yes  25.0
# ...           ...                                     ...      ...   ...
# 64455       64567                                     NaN      Yes   NaN
# 64457       64867                                     NaN      Yes   NaN
# 64458       64898                                     NaN      Yes   NaN
# 64459       64925                                     NaN      Yes   NaN
# 64460       65112                                     NaN      Yes   NaN
#
#       Age1stCode CompFreq  CompTotal  ConvertedComp        Country  \
# ...

# %%
df.sort_values(['Respondent'])
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64157       65634                     I am a developer by profession      Yes
# 64158       65635                     I am a developer by profession      Yes
# 64159       65636                     I am a developer by profession      Yes
# 64160       65637             I am a student who is learning to code      Yes
# 64161       65639             I am a student who is learning to code       No
#
# ...

# %%
df.sort_values(['Respondent'],ascending=False)
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 64161       65639             I am a student who is learning to code       No
# 64160       65637             I am a student who is learning to code      Yes
# 64159       65636                     I am a developer by profession      Yes
# 64158       65635                     I am a developer by profession      Yes
# 64157       65634                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 4               5  I used to be a developer by profession, but no...      Yes
# 3               4                     I am a developer by profession      Yes
# 2               3                        I code primarily as a hobby      Yes
# 1               2                     I am a developer by profession       No
# 0               1                     I am a developer by profession      Yes
#
# ...

# %%
df.sort_values(['Respondent','Age'])
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64157       65634                     I am a developer by profession      Yes
# 64158       65635                     I am a developer by profession      Yes
# 64159       65636                     I am a developer by profession      Yes
# 64160       65637             I am a student who is learning to code      Yes
# 64161       65639             I am a student who is learning to code       No
#
# ...

# %%
df.sort_values(['Age','Respondent'])
# Out:
#        Respondent                              MainBranch Hobbyist  Age  \
# 12271       12310  I am a student who is learning to code      Yes  1.0
# 20042       20122          I am a developer by profession      Yes  1.0
# 25061       25154          I am a developer by profession      Yes  1.0
# 64383       52582                                     NaN      Yes  1.0
# 54687       55797          I am a developer by profession      Yes  1.0
# ...           ...                                     ...      ...  ...
# 64157       65634          I am a developer by profession      Yes  NaN
# 64158       65635          I am a developer by profession      Yes  NaN
# 64159       65636          I am a developer by profession      Yes  NaN
# 64160       65637  I am a student who is learning to code      Yes  NaN
# 64161       65639  I am a student who is learning to code       No  NaN
#
#                  Age1stCode CompFreq     CompTotal  ConvertedComp  \
# ...

# %%
Ethiopia = df[df['Country']=='India']
Ethiopia
# Out:
#        Respondent                              MainBranch Hobbyist   Age  \
# 6               7          I am a developer by profession      Yes   NaN
# 21             22          I am a developer by profession      Yes   NaN
# 57             58          I am a developer by profession      Yes   NaN
# 62             63  I am a student who is learning to code      Yes  21.0
# 147           149          I am a developer by profession      Yes  36.0
# ...           ...                                     ...      ...   ...
# 64391       54757                                     NaN      Yes   NaN
# 64398       55407                                     NaN      Yes   NaN
# 64439       62464                                     NaN      Yes   NaN
# 64442       62954                                     NaN      Yes   NaN
# 64452       64236                                     NaN      Yes   NaN
#
#       Age1stCode CompFreq   CompTotal  ConvertedComp Country  \
# ...

# %%
Ethiopia.reset_index(drop=True)
# Out:
#       Respondent                              MainBranch Hobbyist   Age  \
# 0              7          I am a developer by profession      Yes   NaN
# 1             22          I am a developer by profession      Yes   NaN
# 2             58          I am a developer by profession      Yes   NaN
# 3             63  I am a student who is learning to code      Yes  21.0
# 4            149          I am a developer by profession      Yes  36.0
# ...          ...                                     ...      ...   ...
# 8398       54757                                     NaN      Yes   NaN
# 8399       55407                                     NaN      Yes   NaN
# 8400       62464                                     NaN      Yes   NaN
# 8401       62954                                     NaN      Yes   NaN
# 8402       64236                                     NaN      Yes   NaN
#
#      Age1stCode CompFreq   CompTotal  ConvertedComp Country  \
# ...

# %%
df = pd.read_csv(path)

df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df = pd.set_option('display.max_rows',10)
df

# %%
df = pd.read_csv(path)
df['Age'].nsmallest(8)
# Out:
# 12271    1.0
# 20042    1.0
# 25061    1.0
# 54687    1.0
# 58292    1.0
# 64383    1.0
# 8793     3.0
# 11600    5.0
# Name: Age, dtype: float64

# %%
df.dtypes
# Out:
# Respondent              int64
# MainBranch             object
# Hobbyist               object
# Age                   float64
# Age1stCode             object
#                        ...
# WebframeWorkedWith     object
# WelcomeChange          object
# WorkWeekHrs           float64
# YearsCode              object
# YearsCodePro           object
# Length: 61, dtype: object
